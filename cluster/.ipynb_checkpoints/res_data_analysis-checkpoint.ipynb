# %%
########### Self-customized setting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import sklearn
import math
from numba import jit, float64

#%% Plot Tong's default setting
SMALL_SIZE = 15
MEDIUM_SIZE = 15
BIGGER_SIZE = 15

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['axes.linewidth'] = 3

# %%
df = []
for i in range(1, 51):
    df.append(pd.read_csv('./data/res/added_links_run'+str(i)+'.csv', index_col=0))

# %%
links_added = []
for i in range(len(df)):
    links_added.append(set(df[i]['position in x'].values))

# %%
numLinksAdded = list(map(len, links_added))
plt.figure()
plt.hist(numLinksAdded);
plt.xlabel('Number of links added')
print(np.mean(numLinksAdded), np.std(numLinksAdded))
# Out:
# 126.4 10.12916580968048

# %%
set.intersection(*links_added)
# Out:
# set()

# %%
#set.union(links_added[0], links_added[1])

#list(links_added[0]) + list(links_added[1])

from collections import Counter, OrderedDict
#Counter(links_added)

import functools 
prevOfLinks = Counter(functools.reduce(lambda a,b : list(a)+list(b), links_added))

# %%
#prevOfLinks.items()
from collections import OrderedDict
# prevOfLinksSorted = {k: v for k, v in OrderedDict(sorted(prevOfLinks.items(), key=lambda item: item[1], reverse=True)}
prevOfLinksSorted = OrderedDict(OrderedDict(sorted(prevOfLinks.items(), key=lambda item: item[1], reverse=True)))

#np.argsort(prevOfLinksSorted.values)

# %%
plt.plot(list(range(len(prevOfLinksSorted))), list(prevOfLinksSorted.values()))
plt.xscale('log')
# plt.yscale('log')
plt.xlabel('rank of added link')
plt.ylabel('prevalence of added link')
# Out:
# Text(0, 0.5, 'prevalence of added link')

# %%
from scipy.stats import bernoulli, binom
NUMSIM = 50
xx = range(NUMSIM)
p = np.mean(numLinksAdded) / 10000
probCum = binom.cdf(xx, NUMSIM, p)
prob = binom.pmf(xx, NUMSIM, p)
threshold = np.where(probCum > 1 - 1e-3)[0][0]

numOfSigLinks = np.sum(np.array(list(prevOfLinksSorted.values())) >= threshold)
numOfTotalLinks = np.array(list(prevOfLinksSorted.values())).shape[0]
print('Number of significant links and total links is:')
print(numOfSigLinks, numOfTotalLinks)
print(numOfSigLinks / numOfTotalLinks)

ys_actual, xs_actual = np.histogram(list(prevOfLinksSorted.values()), bins=5, normed=True)

plt.plot(xx, prob, 'o')
ys_actual, xs_actual = np.histogram(list(prevOfLinksSorted.values()), bins=50, normed=True)
plt.plot(xs_actual[1:51], ys_actual, 'o')
plt.plot([threshold, threshold], [0, 1], 'k-.')
plt.yscale('log'); plt.ylim([1e-3, 1])
plt.xlabel('Prevelance of links')
plt.ylabel('Normed frequency / probability')
plt.text(threshold+1, 0.3, str(numOfSigLinks)+' links have the P-value < 1e-3');
#plt.text(threshold+1, 0.5, 'P-value < 1e-3')
# Out:
# Number of significant links and total links is:
# 511 2644
# 0.193267776096823
# /Users/tongwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   from ipykernel import kernelapp as app
# /Users/tongwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.

# %%
pos_sig = list(prevOfLinksSorted.keys())[:numOfSigLinks]
#list(prevOfLinksSorted.values())[:numOfSigLinks]
pos_sig
# Out:
# [10394,
#  6577,
#  8378,
#  10393,
#  6578,
#  6587,
#  8377,
#  8421,
#  8031,
#  1575,
#  9876,
#  11568,
#  7989,
#  8001,
#  8953,
#  11389,
#  11029,
#  10403,
#  10407,
#  8412,
#  11546,
#  9689,
#  8781,
#  8369,
#  753,
#  6086,
#  11580,
#  8225,
#  11416,
#  7979,
#  8361,
#  7455,
#  11386,
#  11661,
#  8080,
#  6621,
#  7926,
#  9588,
#  8364,
#  10020,
#  7285,
#  11022,
#  765,
#  11559,
#  2985,
#  5881,
#  8269,
#  9429,
#  11529,
#  9010,
#  8017,
#  11320,
#  7959,
#  9520,
#  10190,
#  9300,
#  11039,
#  10346,
#  9377,
#  8152,
#  8220,
#  9645,
#  7290,
#  9156,
#  7792,
#  9421,
#  8954,
#  7932,
#  9297,
#  7937,
#  9372,
#  7981,
#  7526,
#  6014,
#  6783,
#  7425,
#  6928,
#  11538,
#  8267,
#  11354,
#  8396,
#  9447,
#  9527,
#  7039,
#  8683,
#  9449,
#  11585,
#  4095,
#  8897,
#  761,
#  7476,
#  11589,
#  6064,
#  6114,
#  11391,
#  8925,
#  8972,
#  11537,
#  8004,
#  5963,
#  6374,
#  10284,
#  10241,
#  4569,
#  9017,
#  8362,
#  11508,
#  6400,
#  7964,
#  11048,
#  9015,
#  8537,
#  1568,
#  9285,
#  5289,
#  8969,
#  6725,
#  8391,
#  9420,
#  9954,
#  11052,
#  11056,
#  11364,
#  8367,
#  6054,
#  10325,
#  8018,
#  4581,
#  4088,
#  8809,
#  7929,
#  11054,
#  7499,
#  8277,
#  10999,
#  8967,
#  8233,
#  10869,
#  9763,
#  8868,
#  7980,
#  6774,
#  6365,
#  11564,
#  10114,
#  10338,
#  6784,
#  7315,
#  9419,
#  8413,
#  11013,
#  10025,
#  9517,
#  8508,
#  11625,
#  8051,
#  10242,
#  9758,
#  8366,
#  6878,
#  4943,
#  9069,
#  8585,
#  9141,
#  10168,
#  9660,
#  4580,
#  9784,
#  5916,
#  11561,
#  8535,
#  11626,
#  9635,
#  8628,
#  6730,
#  11465,
#  8411,
#  6941,
#  2546,
#  10005,
#  780,
#  11034,
#  6450,
#  8009,
#  4910,
#  10086,
#  10616,
#  10118,
#  1424,
#  11058,
#  2532,
#  2210,
#  6856,
#  9059,
#  8586,
#  9636,
#  9257,
#  10961,
#  8521,
#  9012,
#  10264,
#  8385,
#  10437,
#  6809,
#  10017,
#  6709,
#  10482,
#  10994,
#  2553,
#  3660,
#  8651,
#  9492,
#  9338,
#  9538,
#  8082,
#  8249,
#  1598,
#  730,
#  11507,
#  6411,
#  9491,
#  6458,
#  9593,
#  8584,
#  8124,
#  9663,
#  6084,
#  8159,
#  1586,
#  8354,
#  734,
#  11545,
#  9501,
#  9542,
#  8061,
#  6072,
#  10240,
#  8767,
#  9349,
#  11466,
#  225,
#  8945,
#  8191,
#  9472,
#  9650,
#  3041,
#  6132,
#  4603,
#  11387,
#  11393,
#  8387,
#  735,
#  11579,
#  11581,
#  8540,
#  8678,
#  4586,
#  6714,
#  7255,
#  9369,
#  6405,
#  776,
#  11085,
#  8053,
#  2954,
#  9161,
#  10231,
#  10962,
#  737,
#  6372,
#  7935,
#  9493,
#  7464,
#  8513,
#  8247,
#  7288,
#  10957,
#  11526,
#  5917,
#  6012,
#  10312,
#  8915,
#  8940,
#  7934,
#  6746,
#  2162,
#  9933,
#  6180,
#  10361,
#  9996,
#  9060,
#  9687,
#  6342,
#  1625,
#  6339,
#  6349,
#  8555,
#  9637,
#  8258,
#  10330,
#  1634,
#  5914,
#  8987,
#  8068,
#  7661,
#  7799,
#  4952,
#  8036,
#  4967,
#  6107,
#  11400,
#  2220,
#  10047,
#  5306,
#  6904,
#  10123,
#  5315,
#  11517,
#  5994,
#  9348,
#  5954,
#  7782,
#  7306,
#  11652,
#  10960,
#  6050,
#  10648,
#  6607,
#  8007,
#  6683,
#  11553,
#  8751,
#  2102,
#  1593,
#  11338,
#  2129,
#  7789,
#  9327,
#  10360,
#  8360,
#  3761,
#  6870,
#  6378,
#  9132,
#  10262,
#  6699,
#  6702,
#  10859,
#  2172,
#  11394,
#  7861,
#  5848,
#  7433,
#  3854,
#  5919,
#  9533,
#  10048,
#  5964,
#  7517,
#  8565,
#  6103,
#  6108,
#  7720,
#  2111,
#  10309,
#  2177,
#  11410,
#  7938,
#  9487,
#  10067,
#  9061,
#  8557,
#  9084,
#  6058,
#  4538,
#  10176,
#  8210,
#  9292,
#  6785,
#  8873,
#  6843,
#  784,
#  4898,
#  4929,
#  4946,
#  10234,
#  8704,
#  5666,
#  11310,
#  8252,
#  11368,
#  11388,
#  7930,
#  7485,
#  11642,
#  8637,
#  4550,
#  9213,
#  11307,
#  5258,
#  10431,
#  5937,
#  4922,
#  8006,
#  11598,
#  9133,
#  9692,
#  11342,
#  5270,
#  11464,
#  722,
#  5928,
#  5485,
#  8581,
#  10188,
#  4567,
#  5721,
#  6758,
#  2199,
#  11458,
#  11049,
#  6061,
#  2526,
#  9717,
#  5207,
#  9410,
#  7945,
#  11544,
#  4544,
#  8268,
#  6782,
#  2193,
#  6851,
#  6923,
#  6414,
#  8070,
#  6065,
#  980,
#  2570,
#  2615,
#  5738,
#  5853,
#  234,
#  7960,
#  5987,
#  11632,
#  9122,
#  6732,
#  6738,
#  7332,
#  6846,
#  11460,
#  11503,
#  4937,
#  9079,
#  8895,
#  11461,
#  5982,
#  8178,
#  10434,
#  751,
#  11066,
#  9131,
#  959,
#  9204,
#  8729,
#  10906,
#  8961,
#  11552,
#  9510,
#  8506,
#  8179,
#  9444,
#  759,
#  11035,
#  9617,
#  5704,
#  1617,
#  9879,
#  9881,
#  5864,
#  11032,
#  8025,
#  11123,
#  7531,
#  9089,
#  2962,
#  5460,
#  6063,
#  3140,
#  6352,
#  6421,
#  1629,
#  5748,
#  4955,
#  8546,
#  5940,
#  7510,
#  10948,
#  4553,
#  11370,
#  8522,
#  8773,
#  10158,
#  4963,
#  9441,
#  11076,
#  11136,
#  9709,
#  7819,
#  6125]

# %%
df_all = df[0].copy()
for i in range(1, 50):
    df_all = pd.concat([df_all, df[i]])
df_all.set_index('position in x', inplace=True)
df_all.loc[pos_sig]
# Out:
#                metabolite ID  \
# position in x
# 10394                   2134
# 10394                   2179
# 10394                   2229
# 10394                   2155
# 10394                   2122
# 10394                   2133
# 10394                   2201
# 10394                   2049
# 10394                   2151
# 10394                   2111
# 10394                   2179
# 10394                   2041
# 10394                   2240
# 10394                   2237
# 10394                   2240
# 10394                   2151
# 10394                   2147
# 10394                   2228
# 10394                   2229
# 6577                    2198
# 6577                    2240
# 6577                    2228
# 6577                    2240
# 6577                    2133
# 6577                    2190
# 6577                    2237
# 6577                    2240
# 6577                    2154
# 6577                    2183
# 6577                    2133
# ...                      ...
# 10158                   2061
# 10158                   2154
# 4963                    2154
# 4963                    2142
# 4963                    2125
# 4963                    2067
# 9441                    2198
# 9441                    2136
# 9441                    2006
# 9441                    2135
# 11076                   2175
# 11076                   2125
# 11076                   2228
# 11076                   2237
# 11136                   2237
# 11136                   2237
# 11136                   2153
# 11136                   2049
# 9709                    2160
# 9709                    2133
# 9709                    2228
# 9709                    2226
# 7819                    2041
# 7819                    2125
# 7819                    2175
# 7819                    2020
# 6125                    2010
# 6125                    2040
# 6125                    2020
# 6125                    2040
#
#                                                 metabolite names  microbes ID  \
# position in x
# 10394                       L-Glutamine (D-Glutamine, Glutamine)          129
# 10394          Niacin (Vitamin B3, Nicotinic acid, Nicotinate...          952
# 10394                                                    Thymine          119
# 10394                                      L-Tyrosine (Tyrosine)          952
# 10394                        Isovalerate (3-Methylbutanoic acid)          456
# 10394          L-Glutamate (L-Glutamic acid, Glutamate, D-Glu...          952
# 10394                                    Propanoate (Propionate)          161
# 10394                                      Cholic acid (Cholate)          135
# 10394                                L-Serine (Serine, D-Serine)          124
# 10394                                                  Histamine          314
# 10394          Niacin (Vitamin B3, Nicotinic acid, Nicotinate...          135
# 10394                                       Caproate (Hexanoate)            9
# 10394                      Valerate (Pentanoic acid, Pentanoate)          455
# 10394                                                     Uracil          953
# 10394                      Valerate (Pentanoic acid, Pentanoate)          969
# 10394                                L-Serine (Serine, D-Serine)          135
# 10394           L-Phenylalanine (Phenylalanine, D-Phenylalanine)          551
# 10394                                                  Thymidine          134
# 10394                                                    Thymine          460
# 6577                                                    Pimelate          314
# 6577                       Valerate (Pentanoic acid, Pentanoate)          161
# 6577                                                   Thymidine         1064
# 6577                       Valerate (Pentanoic acid, Pentanoate)          968
# 6577           L-Glutamate (L-Glutamic acid, Glutamate, D-Glu...          965
# 6577                 Pantothenic acid (Vitamin B5, Pantothenate)          953
# 6577                                                      Uracil          158
# 6577                       Valerate (Pentanoic acid, Pentanoate)          457
# 6577                                   L-Tryptophan (Tryptophan)          454
# 6577                                   Octanoate (Caprylic acid)          461
# 6577           L-Glutamate (L-Glutamic acid, Glutamate, D-Glu...         1064
# ...                                                          ...          ...
# 10158                                      D-Fructose (Fructose)          131
# 10158                                  L-Tryptophan (Tryptophan)          953
# 4963                                   L-Tryptophan (Tryptophan)          796
# 4963                                         L-Leucine (Leucine)          338
# 4963                              L-Alanine (D-Alanine, Alanine)          123
# 4963                                 D-Glucosamine (Glucosamine)          314
# 9441                                                    Pimelate          953
# 9441                                     L-Histidine (Histidine)          158
# 9441                       2-Aminobutyric acid (2-Aminobutyrate)          125
# 9441                                         L-Glycine (Glycine)          551
# 11076          N-Acetylneuraminic acid (N-acetylneuraminate, ...          137
# 11076                             L-Alanine (D-Alanine, Alanine)          159
# 11076                                                  Thymidine          124
# 11076                                                     Uracil           54
# 11136                                                     Uracil          149
# 11136                                                     Uracil          952
# 11136                                    L-Threonine (Threonine)          455
# 11136                                      Cholic acid (Cholate)          131
# 9709                                                    Malonate          454
# 9709           L-Glutamate (L-Glutamic acid, Glutamate, D-Glu...           54
# 9709                                                   Thymidine          135
# 9709                              Thiamine (Vitamin B1, Thiamin)          461
# 7819                                        Caproate (Hexanoate)          119
# 7819                              L-Alanine (D-Alanine, Alanine)          953
# 7819           N-Acetylneuraminic acid (N-acetylneuraminate, ...          135
# 7819                                                     Adipate          119
# 6125                  4-Aminobenzoate (para-amino, Benzoic acid)          608
# 6125                                                  Cadaverine          129
# 6125                                                     Adipate          129
# 6125                                                  Cadaverine          338
#
#                                               microbes names  edgeType  \
# position in x
# 10394                                     Bacteroides ovatus         3
# 10394                                 Roseburia intestinalis         3
# 10394                                     Bacteroides caccae         3
# 10394                                 Roseburia intestinalis         3
# 10394                                    Eubacterium limosum         3
# 10394                                 Roseburia intestinalis         3
# 10394               Blautia hansenii (Ruminococcus hansenii)         3
# 10394                                  Bacteroides uniformis         3
# 10394                                  Bacteroides eggerthii         3
# 10394                                     Clostridium leptum         3
# 10394                                  Bacteroides uniformis         3
# 10394                             Acidaminococcus fermentans         3
# 10394                                     Eubacterium hallii         3
# 10394                                Roseburia inulinivorans         3
# 10394                                   Ruminococcus torques         3
# 10394                                  Bacteroides uniformis         3
# 10394                                  Holdemania filiformis         3
# 10394                           Bacteroides thetaiotaomicron         3
# 10394                                    Eubacterium siraeum         3
# 6577                                      Clostridium leptum         3
# 6577                Blautia hansenii (Ruminococcus hansenii)         2
# 6577                                Streptococcus salivarius         3
# 6577                                      Ruminococcus obeum         3
# 6577                               Ruminococcus flavefaciens         3
# 6577                                 Roseburia inulinivorans         3
# 6577                       Bifidobacterium pseudocatenulatum         3
# 6577                                     Eubacterium rectale         3
# 6577                                     Eubacterium eligens         3
# 6577                                  Eubacterium ventriosum         3
# 6577                                Streptococcus salivarius         3
# ...                                                      ...       ...
# 10158                                   Bacteroides plebeius         3
# 10158                                Roseburia inulinivorans         3
# 4963                                Odoribacter splanchnicus         3
# 4963                                       Coprococcus comes         2
# 4963                                       Bacteroides dorei         3
# 4963                                      Clostridium leptum         3
# 9441                                 Roseburia inulinivorans         2
# 9441                       Bifidobacterium pseudocatenulatum         2
# 9441           Bacteroides finegoldii (Alistipes finegoldii)         3
# 9441                                   Holdemania filiformis         2
# 11076                              Bacteroides xylanisolvens         3
# 11076                                  Bilophila wadsworthia         3
# 11076                                  Bacteroides eggerthii         3
# 11076                                   Alistipes putredinis         3
# 11136                           Bifidobacterium adolescentis         3
# 11136                                 Roseburia intestinalis         3
# 11136                                     Eubacterium hallii         3
# 11136                                   Bacteroides plebeius         3
# 9709                                     Eubacterium eligens         3
# 9709                                    Alistipes putredinis         2
# 9709                                   Bacteroides uniformis         2
# 9709                                  Eubacterium ventriosum         3
# 7819                                      Bacteroides caccae         3
# 7819                                 Roseburia inulinivorans         3
# 7819                                   Bacteroides uniformis         3
# 7819                                      Bacteroides caccae         3
# 6125                                      Lactococcus lactis         2
# 6125                                      Bacteroides ovatus         2
# 6125                                      Bacteroides ovatus         3
# 6125                                       Coprococcus comes         3
#
#                error reduced  step added
# position in x
# 10394               0.002324        1056
# 10394               0.003670        2531
# 10394               0.000659        2530
# 10394               0.002194        1519
# 10394               0.011789         781
# 10394               0.004399         951
# 10394               0.006507        2849
# 10394               0.004978         637
# 10394               0.002842        1680
# 10394               0.003733         756
# 10394               0.000926        2646
# 10394               0.005604         560
# 10394               0.002299        4789
# 10394               0.004247        3680
# 10394               0.000892        4933
# 10394               0.004251        2001
# 10394               0.013721        1479
# 10394               0.004426        3300
# 10394               0.005081        3530
# 6577                0.002391        2807
# 6577                0.002900         338
# 6577                0.000120        3077
# 6577                0.000800        4480
# 6577                0.000721        1526
# 6577                0.001869        2848
# 6577                0.001229        3213
# 6577                0.001392        4435
# 6577                0.001934        1865
# 6577                0.000490        3174
# 6577                0.001144        1242
# ...                      ...         ...
# 10158               0.002264         552
# 10158               0.000343        2024
# 4963                0.000202        2167
# 4963                0.002616          59
# 4963                0.000669         896
# 4963                0.000288         577
# 9441                0.004167         193
# 9441                0.005931         102
# 9441                0.001023         301
# 9441                0.006878         111
# 11076               0.002121        2028
# 11076               0.000079        1102
# 11076               0.000430        3482
# 11076               0.000093        3568
# 11136               0.000502        3516
# 11136               0.000041        3750
# 11136               0.000786        2050
# 11136               0.000238         830
# 9709                0.000182        1960
# 9709                0.008627          82
# 9709                0.001758         244
# 9709                0.000490        2585
# 7819                0.000970         626
# 7819                0.000223         948
# 7819                0.000032        2651
# 7819                0.000373         509
# 6125                0.000749          14
# 6125                0.000586          27
# 6125                0.000011         368
# 6125                0.000156         567
#
# [3038 rows x 7 columns]

# %%
i=0
df[i][df[i] == 'position in x']
# Out:
#      metabolite ID metabolite names  microbes ID microbes names  edgeType  \
# 0              NaN              NaN          NaN            NaN       NaN
# 1              NaN              NaN          NaN            NaN       NaN
# 2              NaN              NaN          NaN            NaN       NaN
# 3              NaN              NaN          NaN            NaN       NaN
# 4              NaN              NaN          NaN            NaN       NaN
# 5              NaN              NaN          NaN            NaN       NaN
# 6              NaN              NaN          NaN            NaN       NaN
# 7              NaN              NaN          NaN            NaN       NaN
# 8              NaN              NaN          NaN            NaN       NaN
# 9              NaN              NaN          NaN            NaN       NaN
# 10             NaN              NaN          NaN            NaN       NaN
# 11             NaN              NaN          NaN            NaN       NaN
# 12             NaN              NaN          NaN            NaN       NaN
# 13             NaN              NaN          NaN            NaN       NaN
# 14             NaN              NaN          NaN            NaN       NaN
# 15             NaN              NaN          NaN            NaN       NaN
# 16             NaN              NaN          NaN            NaN       NaN
# 17             NaN              NaN          NaN            NaN       NaN
# 18             NaN              NaN          NaN            NaN       NaN
# 19             NaN              NaN          NaN            NaN       NaN
# 20             NaN              NaN          NaN            NaN       NaN
# 21             NaN              NaN          NaN            NaN       NaN
# 22             NaN              NaN          NaN            NaN       NaN
# 23             NaN              NaN          NaN            NaN       NaN
# 24             NaN              NaN          NaN            NaN       NaN
# 25             NaN              NaN          NaN            NaN       NaN
# 26             NaN              NaN          NaN            NaN       NaN
# 27             NaN              NaN          NaN            NaN       NaN
# 28             NaN              NaN          NaN            NaN       NaN
# 29             NaN              NaN          NaN            NaN       NaN
# ..             ...              ...          ...            ...       ...
# 78             NaN              NaN          NaN            NaN       NaN
# 79             NaN              NaN          NaN            NaN       NaN
# 80             NaN              NaN          NaN            NaN       NaN
# 81             NaN              NaN          NaN            NaN       NaN
# 82             NaN              NaN          NaN            NaN       NaN
# 83             NaN              NaN          NaN            NaN       NaN
# 84             NaN              NaN          NaN            NaN       NaN
# 85             NaN              NaN          NaN            NaN       NaN
# 86             NaN              NaN          NaN            NaN       NaN
# 87             NaN              NaN          NaN            NaN       NaN
# 88             NaN              NaN          NaN            NaN       NaN
# 89             NaN              NaN          NaN            NaN       NaN
# 90             NaN              NaN          NaN            NaN       NaN
# 91             NaN              NaN          NaN            NaN       NaN
# 92             NaN              NaN          NaN            NaN       NaN
# 93             NaN              NaN          NaN            NaN       NaN
# 94             NaN              NaN          NaN            NaN       NaN
# 95             NaN              NaN          NaN            NaN       NaN
# 96             NaN              NaN          NaN            NaN       NaN
# 97             NaN              NaN          NaN            NaN       NaN
# 98             NaN              NaN          NaN            NaN       NaN
# 99             NaN              NaN          NaN            NaN       NaN
# 100            NaN              NaN          NaN            NaN       NaN
# 101            NaN              NaN          NaN            NaN       NaN
# 102            NaN              NaN          NaN            NaN       NaN
# 103            NaN              NaN          NaN            NaN       NaN
# 104            NaN              NaN          NaN            NaN       NaN
# 105            NaN              NaN          NaN            NaN       NaN
# 106            NaN              NaN          NaN            NaN       NaN
# 107            NaN              NaN          NaN            NaN       NaN
#
#      error reduced  step added  position in x
# 0              NaN         NaN            NaN
# 1              NaN         NaN            NaN
# 2              NaN         NaN            NaN
# 3              NaN         NaN            NaN
# 4              NaN         NaN            NaN
# 5              NaN         NaN            NaN
# 6              NaN         NaN            NaN
# 7              NaN         NaN            NaN
# 8              NaN         NaN            NaN
# 9              NaN         NaN            NaN
# 10             NaN         NaN            NaN
# 11             NaN         NaN            NaN
# 12             NaN         NaN            NaN
# 13             NaN         NaN            NaN
# 14             NaN         NaN            NaN
# 15             NaN         NaN            NaN
# 16             NaN         NaN            NaN
# 17             NaN         NaN            NaN
# 18             NaN         NaN            NaN
# 19             NaN         NaN            NaN
# 20             NaN         NaN            NaN
# 21             NaN         NaN            NaN
# 22             NaN         NaN            NaN
# 23             NaN         NaN            NaN
# 24             NaN         NaN            NaN
# 25             NaN         NaN            NaN
# 26             NaN         NaN            NaN
# 27             NaN         NaN            NaN
# 28             NaN         NaN            NaN
# 29             NaN         NaN            NaN
# ..             ...         ...            ...
# 78             NaN         NaN            NaN
# 79             NaN         NaN            NaN
# 80             NaN         NaN            NaN
# 81             NaN         NaN            NaN
# 82             NaN         NaN            NaN
# 83             NaN         NaN            NaN
# 84             NaN         NaN            NaN
# 85             NaN         NaN            NaN
# 86             NaN         NaN            NaN
# 87             NaN         NaN            NaN
# 88             NaN         NaN            NaN
# 89             NaN         NaN            NaN
# 90             NaN         NaN            NaN
# 91             NaN         NaN            NaN
# 92             NaN         NaN            NaN
# 93             NaN         NaN            NaN
# 94             NaN         NaN            NaN
# 95             NaN         NaN            NaN
# 96             NaN         NaN            NaN
# 97             NaN         NaN            NaN
# 98             NaN         NaN            NaN
# 99             NaN         NaN            NaN
# 100            NaN         NaN            NaN
# 101            NaN         NaN            NaN
# 102            NaN         NaN            NaN
# 103            NaN         NaN            NaN
# 104            NaN         NaN            NaN
# 105            NaN         NaN            NaN
# 106            NaN         NaN            NaN
# 107            NaN         NaN            NaN
#
# [108 rows x 8 columns]

# %%
ys_actual, xs_actual = np.histogram(list(prevOfLinksSorted.values()), bins=5, normed=True)
print(xs_actual, ys_actual)
# Out:
# [ 1.   4.6  8.2 11.8 15.4 19. ] [0.24300303 0.02742057 0.00556816 0.00136578 0.00042024]
# /Users/tongwang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   """Entry point for launching an IPython kernel.

# %%
numOfSigLinks = np.sum(np.array(list(prevOfLinksSorted.values())) >= threshold)
numOfTotalLinks = np.array(list(prevOfLinksSorted.values())).shape[0]
print(numOfSigLinks, numOfTotalLinks)
print(numOfSigLinks / numOfTotalLinks)
# Out:
# 511 2644
# 0.193267776096823

# %%
df_MAMBO = pd.read_csv("mambo_curated.txt", sep = '\t')
df_MAMBO_filtered_newID = df_MAMBO_filtered[['microbe_ID', 'metabolite_ID']].copy()
df_MAMBO_filtered_newID.columns = ['microbes', 'metabolites']
df_MAMBO_filtered_newID['microbes'] = df_microbes.loc[df_MAMBO_filtered_newID['microbes']].values
df_MAMBO_filtered_newID['metabolites'] = df_metabolites.loc[df_MAMBO_filtered_newID['metabolites']].values
s1 = df_MAMBO_filtered_newID
s2 = net[['metabolites', 'microbes']]
numOverlap = len(pd.merge(s1, s2, how='inner'))
